# %%
from IPython.display import HTML
HTML('''<script>
code_show=true;
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
}
$( document ).ready(code_toggle);
</script>
To toggle on/off the raw code, click <a href="javascript:code_toggle()">here</a>.''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# To toggle on/off the raw code, click <a href="javascript:code_toggle()">here</a>.

# %%
def printred(skk): print("\033[91m {}\033[00m" .format(skk))
printred('--------------------------------------')
printred('\033[1m'+'  PORT UI REGTEST v2.0 by MMAIOCCHI1'+'\033[1m')
printred('--------------------------------------')
print(' ')

from main.port_regtest import app
app.run()
# Out:
#  --------------------------------------
#    PORT UI REGTEST v2.0 by MMAIOCCHI1
#  --------------------------------------
# VBox(children=(HBox(children=(Dropdown(description='Input : ', options=('CUSTOM', 'NXQC', 'RISK', 'HIPPO', ' '…
